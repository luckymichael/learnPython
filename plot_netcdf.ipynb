# %%
# %matplotlib inline
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec

# %%
tfreeze = 273.16
tzero   = 273.15

ds_all = xr.open_dataset(r"D:\Cloud\Dropbox\postdoc\summa\summaData\problematicHRU\snow_too_low\191501.nc")

# %%
(ds_all.airtemp - tfreeze).plot()

# %%
ds_all.airpres.plot()

# %%
(ds_all.pptrate * 3600).plot(label = 'pptrate')

# %%
ds_all.LWRadAtm.plot(label = 'pptrate')

# %%
ds_all.SWRadAtm.plot(label = 'pptrate')

# %%
ds_all.spechum.plot()

# %%
ds_all.windspd.plot()
